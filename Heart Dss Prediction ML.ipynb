# %% [markdown]
# ## Heart Disease Prediction Project
# Data available on Kaggle: https://www.kaggle.com/datasets/redwankarimsony/heart-disease-data/dataedicted attribute

# %%
#Import models


import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
# %matplotlib inline 

#Scikit learn models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# Model Evaluations
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score

# %% [markdown]
# ### Load Data

# %%
df = pd.read_csv("heart-disease.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
len(df)
# Out:
# 303

# %%
df["target"].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
#Visualize the target column to see distribution of the variables

df["target"].value_counts().plot(kind="bar", color=["orange", "lightblue"], figsize=(4,2));

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
 df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# ### Some EDA

# %% [markdown]
# #### Compare "Sex" column to the "Target" column

# %%
# Check distribution of sex 
df["sex"].value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
pd.crosstab(df.target, df.sex)
# Out:
# sex      0    1
# target
# 0       24  114
# 1       72   93

# %%
pd.crosstab(df.target, df.sex).plot(kind="bar", color=["orange", "lightblue"], figsize=(6,4))
plt.title("Heart Disease Frequency for Sex")
plt.xlabel("0=No Disease, 1=Disease")
plt.ylabel("Amount")
plt.legend(["Female", "Male"])   #Renames Legend
plt.xticks(rotation=0); #Rotates X-axis labels (0&1)

# %% [markdown]
# #### Check Age distribution

# %%
df["age"].plot.hist(figsize=(6,4));

# %% [markdown]
# #### Compare Age distribution against the Target

# %%
#We have to create age bins due to the number of multiple ages we get

# Create age bins
age_bins = [20,30,40,50,60,70,80]
age_labels = ['20-29', '30-39', '40-49', '50-59', '60-69', '70-79']
df['Age Group'] = pd.cut(df['age'], bins=age_bins, labels=age_labels, right=False)

# Use crosstab to compare age bins with target
crosstab_result = pd.crosstab( df['Age Group'], df['target'])

# Plot the comparison
ax = crosstab_result.plot(kind='bar', figsize=(6, 4))

# Add data labels
for container in ax.containers:
    ax.bar_label(container, label_type='edge')
    
plt.title('Target Distribution Across Age Bins')
plt.xlabel('Age Group')
plt.ylabel('Proportion')
plt.legend(title='Target', loc='upper right')
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# #### Age vs Heart Rate(Thalach) for Heart Dss

# %%
#Create a figure
plt.figure(figsize=(6,4))

#Scatter with positive examples
plt.scatter(df.age[df.target==1],  #Where Target= 1
            df.thalach[df.target==1],
            c="salmon")

plt.scatter(df.age[df.target==0],  #Where Target= 0
            df.thalach[df.target==0],
            c="lightblue")
#Add some helful info
plt.title("Heart dss in function of Age and Max Heart Rate (Thalach)")
plt.xlabel("Age")
plt.ylabel("Max Heart Rate")
plt.legend(["Disease", "No Disease"]);

# %% [markdown]
# #### Compare Chestpain to Target

# %%
pd.crosstab(df.cp, df.target).plot(kind="bar", color=["orange", "lightblue"], figsize=(6,4))
plt.title("Heart Disease Frequency for Sex")
plt.xlabel("Chest pain type")
plt.ylabel("Amount")
plt.legend(["No Disease", "Disease"])   #Renames Legend
plt.xticks(rotation=0); #Rotates X-axis labels (0&1)

# %% [markdown]
# #### Lets check correlation of all our independent variable(features) with the dependent variable(target)

# %%
#Make a correlation
df.corr()
# Out:
# C:\Users\afolabi.ajao\AppData\Local\Temp\ipykernel_24784\1193452694.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# ...

# %%
#Lets make visualize correlation using seaborn

correlation_matrix = df.corr(numeric_only=True)

# Set up the matplotlib figure
plt.figure(figsize=(8, 6))

# Create the heatmap using seaborn
ax = sns.heatmap(correlation_matrix, 
                annot=True, 
                cmap='YlGnBu', 
                fmt='.2f', 
                linewidths=0.5);

# Display the heatmap
plt.show()

#Below code is included if the first and last row is cut off
# bottom, top = ax.get_ylim()    
# ax.set_ylim(bottom + 0.5, top - 0.5)

# %% [markdown]
# ### Modelling

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target Age Group
# 0   0     1       1     60-69
# 1   0     2       1     30-39
# 2   0     2       1     40-49
# 3   0     2       1     50-59
# 4   0     2       1     50-59

# %%
df = df.drop("Age Group", axis=1)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
len(df)
# Out:
# 303

# %%
#SPlit Data into X and Y

X = df.drop("target", axis=1)
y=df["target"]

# %%
X.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal
# 0   0     1
# 1   0     2
# 2   0     2
# 3   0     2
# 4   0     2

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: target, dtype: int64

# %%
np.random.seed(42)

#Split into Train, Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(X_train), len(X_test)
# Out:
# (242, 61)

# %%
len(y_train), len(y_test)
# Out:
# (242, 61)

# %% [markdown]
# ### Building ML model

# %%
#### Logistic Regression
